# %% [markdown]
# # Sets with Python
# ---------------------------
#
# ## 1. Creating Sets
#
# Sets are unordered collections of UNIQUE elements.
# Python automatically removes duplicates when creating a set.
#
# ### 1.1 Creating a set by converting a list

# %%
# Create a set from a list with duplicate values arbitrary ordering using [ ]

A_list =

# convert list to a set A
A =

# %% [markdown]
# ### 1.2 Creating a set directly

# %%
# Create another set directly using curly braces { }

# %% [markdown]
# --------------------------------

# %% [markdown]
# ## 2. Membership testing

# %%
# We can check if an element exists in a set using the 'in' keyword.
# This is a very fast operation in sets.

a = 3

# %% [markdown]
# ---------------------------

# %% [markdown]
# ## 3. Core Set Operations

# %% [markdown]
# ### 3.1 Union
#
# $C = A \cup B$

# %% [markdown]
# ### 3.2 Intersection
#
# $D = A \cap B$

# %%
D =
# or
D =

print("D = ", D)

# %% [markdown]
# ### 3.3 Set Difference
# $E = A \setminus B$

# %%
# Difference: Elements that are in Set A but NOT in Set B.
# Mathematical Notation: A - B or A \ B

E = ...
print("E = ", E)

# or

E = ...

print("E = ", E)

# %% [markdown]
# ### 3.2 Symmetric Difference
# $F = A ~\triangle ~B$
#
# **Elements that are in either set, but NOT in both.**
#
# It's like $F = (A \cup B) - (A \cap B)$.

# %%
# A.symmetric_differnce(B)

F =
print("F = ", F)

# or

F =
print("F = ", F)


# You can also use the caret operator: A ^ B

F =
print("F = ", F)

# %% [markdown]
# Let's show that $A~\triangle~B = (A \cup B) - (A \cap B)$.

# %%
F1 = ...
print("F1 = ", F1)

F==F1

# %% [markdown]
# ------------------

# %% [markdown]
# ## 4. Set Relationships

# %% [markdown]
# ### 4.1 is Subset?
#
# $a \subseteq A $ -- is $a$ a subset of $A$ ?

# %%
a = {1,2,5}
A = {-1,0,1,2,3,4,5}

# is a subset of A?

# %%
b = {1,2,4,8}
A = {-1,0,1,2,3,4,5}

# is b subset of A?

# %% [markdown]
# ### 4.2 is Superset?
#
# Superset is simply is "opposite" of "subset"
#
# $ C = A \supseteq a$ -- is $A$ is superset of $a$? -- the same as asking "is $a$ is subset of $A$" ?

# %%
# is a superset of A?

# %%
# is A superset of a?

# %% [markdown]
# # 5. Convert set to a list

# %%
H = {1,2,4,5,2,3,9,7,1,-4}
print("This is set H = ", H)
# Out:
# This is set H =  {1, 2, 3, 4, 5, 7, 9, -4}

# %%
H_list=list(H)
print("This is list H_list = ", H_list)
# Out:
# This is list H_list =  [1, 2, 3, 4, 5, 7, 9, -4]
